# %% [markdown]
# <a href="https://colab.research.google.com/github/razan-wari/Gaza-Sky-Geeks/blob/main/Fraud_Dediction_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
fraud_dediction = pd.read_csv('/content/data2.csv')
fraud_dediction.head()
# Out:
#   Profession  Income   Credit_card_number Expiry  Security_code  Fraud
# 0     DOCTOR   42509     3515418493460774  07/25            251      1
# 1     DOCTOR   80334      213134223583196  05/32            858      1
# 2     LAWYER   91552     4869615013764888  03/30            755      1
# 3     LAWYER   43623      341063356109385  01/29            160      1
# 4     DOCTOR   22962  4707418777543978402  11/30            102      0
