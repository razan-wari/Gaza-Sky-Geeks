# %% [markdown]
# <a href="https://colab.research.google.com/github/razan-wari/Gaza-Sky-Geeks/blob/main/customer_support.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

#importing the libraries
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
customer_support = pd.read_csv('/content/Customer_support_data.csv')
customer_support.head()
customer_support.info
customer_support.describe()
customer_support.columns
sns.pairplot(customer_support)
plt.show()
